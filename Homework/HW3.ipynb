# %% [markdown]
# #**CS6140 - Machine Learning, Spring 2024**
# ##**Homework 3**
#
# Submission Instructions:
# - Please complete this homework assignment in the same notebook provided.
# - Submit your completed assignment on Canvas by the deadline.
#
# Submission Deadline:
# **March 29th, 2024**
#
# <p align="justify">
# Please read the instructions carefully when answering questions and ensure your code works correctly before submission. The grader will run your code for grading the coding questions.
# </p>

# %%
#@markdown ### Enter your first and last names below:
First Name = "" #@param {type:"string"}
Last Name = "" #@param {type:"string"}

# %% [markdown]
# #**Marijuana Legalization**
#
# The General Social Survey (GSS), conducted biannually by the National Opinion Research Center (NORC), serves as a critical tool for tracking shifts in American beliefs and attitudes. One prominent trend highlighted by the survey is the evolving perspective on marijuana legalization. In 1973, when the GSS first included the question of legalizing marijuana, only 19% of Americans supported it. However, over the last two decades, there has been a significant shift in attitudes, driven in part by changes in state laws. The legalization of medical marijuana in California in 1996 marked a turning point, followed by landmark decisions in 2012 when Colorado and Washington became the first U.S. states to legalize recreational marijuana use. This shift has continued, with 19 states now allowing recreational use and 37 states permitting medicinal use of marijuana.
#
# **Exploring Support for Marijuana Legalization**
#
# Data from surveys like the General Social Survey (GSS) helps researchers understand connections between personal beliefs and opinions, such as the influence of political affiliation on support for marijuana legalization. The 2021 GSS data is used to investigate how a person's age, education, and political views relate to their stance on marijuana legalization.
#
#
# **Import the GSS dataset and visualize age, education, and political views distribution in relation to support for marijuana legalization.**

# %%
# Import packages and data

# YOUR CODE GOES HERE

# Set seed and test proportion
seed = 123

marijuana = pd.read_csv('https://raw.githubusercontent.com/mh2t/DS5110/main/data/gss.csv').dropna()

# %%
# Plot all three features

plt.rcParams["figure.figsize"] = (20, 6)

plt.subplot(1, 3, 1)
# YOUR CODE GOES HERE

plt.subplot(1, 3, 2)
# YOUR CODE GOES HERE

plt.subplot(1, 3, 3)
# YOUR CODE GOES HERE

plt.show()

# %% [markdown]
# **Explaining Marijuana Legalization with Decision Trees**
#
#
# Decision trees are a suitable choice for researchers aiming to explain relationships. They provide a visual representation of factors related to marijuana legalization support, although they can't capture individual beliefs due to the model's simplicity. However, they're valuable for understanding population-level trends.
#
# **Decision tree with depth=2**
#
# **Build a decision tree to predict support for marijuana legalization. Political views are numerically scaled, with blue indicating support and orange indicating opposition.**

# %%
# Define input and output features
X = marijuana[['age', 'educ', 'polviews_num']]
y = marijuana[['marijuana01']]

# %%
# Initialize and fit the model

# YOUR CODE GOES HERE

# %%
# Resize the plotting window

# YOUR CODE GOES HERE

# %%
# Confusion matrix

# YOUR CODE GOES HERE

# %% [markdown]
# **Expanding the Decision Tree**
#
# Increasing the depth of a decision tree improves prediction accuracy but reduces interpretability. For prediction tasks, a complex model is acceptable, while for explanatory purposes, a simpler model may be preferred.
#
# **Decision Tree with depth=3**
#
#
# **Create a decision tree to predict support for marijuana legalization based on political views, visualizing results in blue for support and orange for lack of support.**

# %%
# Initialize and fit the model

# YOUR CODE GOES HERE

# %%
# Resize the plotting window

# YOUR CODE GOES HERE

# %%
# Confusion matrix

# YOUR CODE GOES HERE

# %% [markdown]
# **Feature Importance**
#
#
# Decision trees can overfit, but for explanatory purposes, this is less concerning. However, they don't measure feature importance. Random forests, composed of many decision trees, offer a solution. They sample data and features differently for each tree, allowing feature importance assessment based on their contribution to the ensemble. Feature importance quantifies average impurity decrease across the random forest's decision trees, highlighting features that performed well.
#
#
# **Create a random forest to predict support for legalizing marijuana, and visualizes feature importance.**

# %%
# Initialize and fit the model

# YOUR CODE GOES HERE
# Out:
# RandomForestClassifier(max_depth=2, max_features=2, random_state=123)

# %%
# Feature importance

# YOUR CODE GOES HERE
# Out:
#         feature  importance
# 2  polviews_num    0.581462
# 0           age    0.387531
# 1          educ    0.031008

# %%
# Plot feature importance

# YOUR CODE GOES HERE

plt.show()
# Out:
# <ipython-input-17-01249cfeaedc>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   p.set_xticklabels(['Political views', 'Age', 'Education'], size=12)

# %%
# Confusion matrix

# YOUR CODE GOES HERE
